# %%
CITY_NAME = "Seattle"

# %%
# Download GeoDataFrame of all boba shops in a particular city using Yelp API.
# Reference: https://boba-nyc.datalife.nyc/data-wrangling.html
# Writes to "./data/<city>_boba_shops.csv"

# importing libraries
import os
import pandas as pd
import geopandas as gpd
import requests
import osmnx as ox

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# saving yelp api key as an environment variable
API_KEY = os.environ.get("yelp_api")

# %%
# our offset parameter - each page 50 rows
offset = 0
print("initial offset number: {}".format(offset))

lst = []

# loop through the api 20 times (limit is 1000 rows with each page includes 50 rows)
for i in range(20):    
    try:
        headers = {"Authorization": "Bearer {}".format(API_KEY)}
        search_api_url = "https://api.yelp.com/v3/businesses/search"
        params = {"term": "bubble tea", 
                  "categories": "bubbletea, boba",
                  "location": CITY_NAME,
                  "offset": offset,
                  "limit": 50}

        response = requests.get(search_api_url, 
                                headers=headers, 
                                params=params, 
                                timeout=10)

        # return a dictionary
        data_dict = response.json()
        
        # convert the business dictionary to a pandas dataframe and append to list
        data = pd.DataFrame(data_dict["businesses"])
        lst.append(data)
      
        # add 50 to the offset to access a new page
        offset += 50
        print("current offset number: {}".format(offset))
        
    except Exception as ex:
        print("exception: {}\nexit loop.".format(ex))
        break
# Out:
# initial offset number: 0
# current offset number: 50
# current offset number: 100
# current offset number: 150
# current offset number: 200
# current offset number: 250
# current offset number: 300
# current offset number: 350
# current offset number: 400
# current offset number: 450
# current offset number: 500
# current offset number: 550
# current offset number: 600
# current offset number: 650
# current offset number: 700
# current offset number: 750
# current offset number: 800
# current offset number: 850
# current offset number: 900
# current offset number: 950
# current offset number: 1000

# %%
# concatenate all pages to one dataframe and reset index
df = pd.concat(lst)
df = df.reset_index(drop=True)

# review shape of dataframe
rows, columns = df.shape
print()
print("query includes {:,} rows and {} columns.".format(rows, columns))
print("row id is unique: {}.".format(df["id"].is_unique))

# review if dataframe id is unique, if not drop duplicates
if df["id"].is_unique == False:
    duplicates = df.loc[df.duplicated(subset=["id"])]
    vals = list(duplicates.head()["name"].values)
    print("\nduplicates found: {}.".format(vals))
    
    df = df.drop_duplicates(subset=["id"]).reset_index(drop=True)
    print("dropping duplicates...")
    
    rows, columns = df.shape
    print("\nrow id is unique: {}.".format(df["id"].is_unique))
    print("query includes {:,} rows and {} columns.".format(rows, columns))


# explode coordinates to create an individual column
gdf = pd.concat([df, df["coordinates"].apply(pd.Series)], axis=1)

# retrieve lat, lon values and return a geodataframe
gdf = gpd.GeoDataFrame(gdf, crs=4326, geometry=gpd.points_from_xy(gdf.longitude, gdf.latitude))

print(gdf.head())
# Out:
# query includes 233 rows and 16 columns.
# row id is unique: True.
#                        id                     alias              name  \
# 0  Hy2xR9KLqu9yzLgk8HD4Ww  chicha-san-chen-bellevue   CHICHA San Chen
# 1  gp8frponQ2ok2DF7H_aqkg      xing-fu-tang-seattle      Xing Fu Tang
# 2  nDvwrhWdB7kjIwn2Z83lSQ  seattle-best-tea-seattle  Seattle Best Tea
# 3  gDNr3c5tsaeWXVDkKRrm2A   dont-yell-at-me-seattle   Dont Yell At Me
# 4  AZWPfcWcF8utdCfyTE48jA          drip-tea-seattle          DRIP TEA
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/IDWbst...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/zWO33c...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/uxsrWj...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/7z-feo...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/9YrXO9...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/chicha-san-chen-belle...           199
# 1  https://www.yelp.com/biz/xing-fu-tang-seattle?...           131
# 2  https://www.yelp.com/biz/seattle-best-tea-seat...           592
# 3  https://www.yelp.com/biz/dont-yell-at-me-seatt...           391
# 4  https://www.yelp.com/biz/drip-tea-seattle?adju...           384
#
#                                           categories  rating  \
# 0    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 1    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
# 2  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 3    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.5
# 4    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}]     4.0
#
#                                         coordinates        transactions  \
# 0     {'latitude': 47.613, 'longitude': -122.19972}                  []
# 1  {'latitude': 47.612275, 'longitude': -122.33921}  [delivery, pickup]
# 2   {'latitude': 47.59846, 'longitude': -122.32731}  [delivery, pickup]
# 3   {'latitude': 47.66163, 'longitude': -122.31339}  [delivery, pickup]
# 4    {'latitude': 47.61335, 'longitude': -122.3192}          [delivery]
#
#                                             location         phone  \
# 0  {'address1': '308 105th Ave NE', 'address2': N...  +14256981933
# 1  {'address1': '1905 4th Ave', 'address2': None,...  +12067658069
# 2  {'address1': '506 S King St', 'address2': '', ...  +12067499855
# 3  {'address1': '4511 University Way NE', 'addres...  +12065880719
# 4  {'address1': '1416 10th Ave', 'address2': '', ...  +12064574374
#
#     display_phone     distance price   latitude  longitude  \
# 0  (425) 698-1933  9768.746948   NaN  47.613000 -122.19972
# 1  (206) 765-8069   720.042644   NaN  47.612275 -122.33921
# 2  (206) 749-9855  1766.108674     $  47.598460 -122.32731
# 3  (206) 588-0719  5414.665108    $$  47.661630 -122.31339
# 4  (206) 457-4374   826.621989    $$  47.613350 -122.31920
#
#                       geometry
# 0  POINT (-122.19972 47.61300)
# 1  POINT (-122.33921 47.61227)
# 2  POINT (-122.32731 47.59846)
# 3  POINT (-122.31339 47.66163)
# 4  POINT (-122.31920 47.61335)

# %%
# Clip data to the city
city_gdf = ox.geocode_to_gdf({ "city": CITY_NAME })
print(city_gdf["geometry"][0])

print(city_gdf["geometry"][0].bounds)

gdf = gpd.clip(gdf, city_gdf)
gdf = gdf.reset_index(drop=True)

rows, columns = gdf.shape
print("Final GeoDataFrame:")
print("number of rows: {}\n\
number of columns: {}".format(rows, columns))
# Out:
# POLYGON ((-122.459696 47.674269, -122.45962 47.672697, -122.45962 47.671118, -122.459559 47.669539, -122.459437 47.668478, -122.45904 47.666472, -122.458582 47.664381, -122.458246 47.663343, -122.457804 47.66197, -122.457087 47.660009, -122.456446 47.658415, -122.455927 47.657148, -122.455469 47.655836, -122.455012 47.654608, -122.45463 47.653494, -122.454447 47.652655, -122.4540965 47.6521951, -122.453974 47.650824, -122.453592 47.649237, -122.453257 47.647314, -122.453103 47.646268, -122.452997 47.645552, -122.452813 47.644018, -122.452615 47.64208, -122.452554 47.639792, -122.452554 47.638765, -122.452554 47.638113, -122.452737 47.636351, -122.452935 47.634916, -122.453195 47.633673, -122.453454 47.632628, -122.453912 47.631392, -122.454171 47.630247, -122.454346 47.629627, -122.454492 47.62911, -122.45469 47.627966, -122.454751 47.627089, -122.454751 47.626204, -122.45289 47.622656, -122.449533 47.617646, -122.447743 47.614765, -122.446801 47.598135, -122.4477 47.595562, -122.450161 47.588522, -122
    addr = f"{loc['address1']}, {loc['city']}, {loc['zip_code']}"

    print(f"Attempting to geocode {addr:>50}... ", end="")
    try:
        lat, long = ox.geocoder.geocode(addr)
        print(f"Found: {lat, long}")

        gdf.loc[index,"geometry"] = Point(long, lat)

    except Exception as e:
        print(f"Not found. Dropping row.")
        gdf.drop(index=index, axis=0)
# Out:
# Attempting to geocode                      600 5th Ave S, Seattle, 98104... Found: (47.5972782, -122.327447)
# Attempting to geocode                      519 6th Ave S, Seattle, 98104... Found: (47.5977153, -122.3265439)
# Attempting to geocode                    618 S Weller St, Seattle, 98104... Found: (47.5976337, -122.3255237)
# Attempting to geocode                      619 S King St, Seattle, 98104... Found: (47.5982488, -122.3254928)
# Attempting to geocode                      679 S King St, Seattle, 98104... Found: (47.5982404, -122.3239502)
# Attempting to geocode                  1043 S Jackson St, Seattle, 98104... Found: (47.5988089, -122.317458)
# Attempting to geocode                        613 9th Ave, Seattle, 98104... Found: (47.6059309, -122.3253983)
# Attempting to geocode                      1150 11th Ave, Seattle, 98122... Found: (47.6126016, -122.317964)
# Attempting to geocode                      1416 10th Ave, Seattle, 98122... Found: (47.6133604, -122.3192083)
# Attempting to geocode                   9025 25th Ave SW, Seattle, 98106... Found: (47.5226736, -122.3655616)
# Attempting to geocode                   9025 25th Ave SW, Seattle, 98106... Found: (47.5226736, -122.3655616)
# Attempting to geocode               4800 Delridge Way SW, Seattle, 98106... Found: (47.559152, -122.362776)
# Attempting to geocode                   4740 42nd Ave SW, Seattle, 98116... Found: (47.5601093, -122.3846068)
# Attempting to geocode                   4611 36th Ave SW, Seattle, 98126... Found: (47.5617127, -122.3777685)
# Attempting to geocode             3217 California Ave SW, Seattle, 98116... Found: (47.57537702020202, -122.38688216161616)
# Attempting to geocode                   2622 Alki Ave SW, Seattle, 98116... Found: (47.58008475, -122.4074340323934)
# Attempting to geocode                   2532 Alki Ave SW, Seattle, 98116... Found: (47.5805845, -122.4063283)
# Attempting to geocode                 1619 Harbor Ave SW, Seattle, 98126... Found: (47.5891426, -122.38146674272434)
# Attempting to geocode                      506 S King St, Seattle, 98104... Found: (47.598475, -122.3273183)
# Attempting to geocode                   223 5th Avenue S, Seattle, 98104... Found: (47.600617877551024, -122.32778167346939)
# Attempting to geocode                       1422 2nd Ave, Seattle, 98101... Found: (47.6086157755102, -122.33814895918367)
# Attempting to geocode                               None, Seattle, 98101... Not found. Dropping row.
# Attempting to geocode                       1905 4th Ave, Seattle, 98101... Found: (47.6122988, -122.3391678)
# Attempting to geocode                       1629 6th Ave, Seattle, 98101... Found: (47.6128434, -122.3362326)
# Attempting to geocode   7101 Martin Luther King Jr Way S, Seattle, 98118... Found: (47.5384086, -122.2829708)
# Attempting to geocode   6951 Martin Luther King Jr Way S, Seattle, 98118... Found: (47.5391664, -122.283133)
# Attempting to geocode   6408 Martin Luther King Jr Way S, Seattle, 98118... Found: (47.54503095, -122.28462267473077)
# Attempting to geocode   6014 Martin Luther King Jr Way S, Seattle, 98118... Found: (47.5475727, -122.285651)
# Attempting to geocode                 2931 Rainier Ave S, Seattle, 98144... Found: (47.5769191, -122.2973684)
# Attempting to geocode             4505 University Way NE, Seattle, 98105... Found: (47.6614794, -122.313301)
# Attempting to geocode                    1100 NE 45th St, Seattle, 98105... Found: (47.6615194, -122.3163483)
# Attempting to geocode             4511 University Way NE, Seattle, 98105... Found: (47.6616878, -122.313289)
# Attempting to geocode             4524 University Way NE, Seattle, 98105... Found: (47.6620812, -122.3129464)
# Attempting to geocode              4545 Roosevelt Way NE, Seattle, 98105... Found: (47.6620497, -122.3177052)
# Attempting to geocode             4553 University Way NE, Seattle, 98105... Found: (47.6627944, -122.3134356)
# Attempting to geocode               4701 Brooklyn Ave NE, Seattle, 98105... Found: (47.6632829, -122.31456474331276)
# Attempting to geocode                   4708 11th Ave NE, Seattle, 98105... Found: (47.6634934, -122.3161723)
# Attempting to geocode             4730 University Way NE, Seattle, 98105... Found: (47.6636997, -122.3129525)
# Attempting to geocode             4725 University Way NE, Seattle, 98105... Found: (47.6638406, -122.3133253)
# Attempting to geocode             4727 University Way NE, Seattle, 98105... Found: (47.663792, -122.3133443)
# Attempting to geocode             5000 University Way NE, Seattle, 98105... Found: (47.6652428, -122.312867)
# Attempting to geocode               5001 Brooklyn Ave NE, Seattle, 98105... Found: (47.66512325, -122.31455140146471)
# Attempting to geocode                    1000 NE 50th St, Seattle, 98105... Found: (47.6652711, -122.3171865)
# Attempting to geocode              5210 Roosevelt Way NE, Seattle, 98105... Found: (47.6668189, -122.3171951)
# Attempting to geocode                    1026 NE 65th St, Seattle, 98115... Found: (47.6759659, -122.3162646)
# Attempting to geocode               7130 Woodlawn Ave NE, Seattle, 98115... Found: (47.6802556, -122.324486)
# Attempting to geocode               7214 Woodlawn Ave NE, Seattle, 98115... Found: (47.6809727, -122.3248217)
# Attempting to geocode                 321 NE Thornton Pl, Seattle, 98125... Found: (47.7024574, -122.3245444)
# Attempting to geocode                 3601 Fremont Ave N, Seattle, 98103... Found: (47.6518072, -122.350194)
# Attempting to geocode                  4207 Gilman Ave W, Seattle, 98199... Found: (47.6577752, -122.3892433)
# Attempting to geocode                     2110 N 45th St, Seattle, 98103... Found: (47.661502, -122.333122)
# Attempting to geocode                     1218 N 45th St, Seattle, 98103... Found: (47.6615362, -122.3424975)
# Attempting to geocode                  2215 NW Market St, Seattle, 98107... Found: (47.6685142, -122.3855842)
# Attempting to geocode                   6421 15th Ave NW, Seattle, 98107... Found: (47.6757657, -122.3766678)
# Attempting to geocode                  7815 Aurora Ave N, Seattle, 98103... Found: (47.6859691, -122.3447158)
# Attempting to geocode                 13200 Aurora Ave N, Seattle, 98133... Found: (47.7246207, -122.3436423)
# Attempting to geocode                   8507 35th Ave NE, Seattle, 98115... Found: (47.6903134, -122.291147)
# Attempting to geocode             11064 Lake City Way NE, Seattle, 98125... Found: (47.71007845, -122.30010770966955)
# Attempting to geocode              14314 Greenwood Ave N, Seattle, 98133... Found: (47.7328992, -122.3550341)

# %%
# save file
save_path = f"./data/{CITY_NAME.lower()}_boba_shops.csv"
gdf.to_csv(save_path, index=False)
print(f"Saved boba shops in {CITY_NAME} to {save_path}")
# Out:
# Saved boba shops in Seattle to ./data/seattle_boba_shops.csv
